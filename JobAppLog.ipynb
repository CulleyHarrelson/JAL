# %% [markdown]
# # Job Application Log - JAL
#
#
# The goal of this project is to allow for quickly saving the job description details associated with a job application and then to do analysis on the data collected.
#
# This notebook compliments the main JAL.py dashboard - it is used for development and testing.

# %%
import requests
from bs4 import BeautifulSoup
import os
import re
import panel as pn
import json
import pandas as pd
import datetime as dt
import altair as alt

pn.extension()
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %% [markdown]
# ### Directories
#
# Data is stored in a folder named **jobs**. In this folder, the html is stored in the **html** sub-directory.  The Job Details data is stored in the **raw** sub-directory, and the extracted data is stored in the **json** sub-directory.

# %%
def get_directories():
    
    return_dict = {}
    jobs_directory = "jobs"
    return_dict['html'] = os.path.join(jobs_directory, 'html')
    return_dict['raw'] = os.path.join(jobs_directory, 'raw')
    return_dict['json'] = os.path.join(jobs_directory, 'json')
    
    if not os.path.exists(jobs_directory):
        os.mkdir(jobs_directory)

    if not os.path.exists(return_dict['html']):
        os.mkdir(return_dict['html'])
    
    if not os.path.exists(return_dict['raw']):
        os.mkdir(return_dict['raw'])
        
    if not os.path.exists(return_dict['json']):
        os.mkdir(return_dict['json'])
    return return_dict
        

directories = get_directories()

print(directories)
# Out:
# {'html': 'jobs/html', 'raw': 'jobs/raw', 'json': 'jobs/json'}

# %% [markdown]
# # Test LinkedIn Job Data Parser
#
# "LinkedIn Job Details" are not available in the raw html file, so they are copy and pasted into the dashboard.  This code block is used to test the regular expressions.

# %%
test_data1 = """Principal Data Security Software Engineer
Roblox · San Mateo, CA (Hybrid) Reposted  2 weeks ago  · 29 applicants
$315,850/yr - $383,910/yr (from job description) · Full-time · Mid-Senior level
1,001-5,000 employees · Software Development
1 company alum works here
Skills: Cryptography, Application Security, +8 more
View verifications related to this job post.View verifications related to this job post.
Show all
"""

test_data2 = """Data Engineering Lead
Genentech · South San Francisco, CA  1 week ago  · 41 applicants
$172,500/yr - $320,300/yr (from job description) · Full-time · Associate
10,001+ employees · Biotechnology Research
Skills: Data Modeling, Data Architecture, +8 more
View verifications related to this job post.View verifications related to this job post.
Show all
"""

test_data3 = """Security Infrastructure DevOps Engineer, SEAR
Apple · Cupertino, CA Reposted  1 hour ago  · 238 applicants
$130,000/yr - $242,000/yr (from job description) · Full-time
10,001+ employees · Computers and Electronics Manufacturing
9 company alumni work here
Skills: Information Security Analysis, Independent Thinking, +8 more
View verifications related to this job post.View verifications related to this job post.
Show all
"""

test_data4 = """Lead software engineer (infrastructure)
AI Fund · San Francisco County, CA Reposted  1 hour ago  · 50 applicants
Full-time · Mid-Senior level
11-50 employees · Venture Capital and Private Equity Principals
Skills: Amazon Web Services (AWS), Optimization, +8 more
"""

test_data5 = """Service Team Lead II- Global Fix Experience
Uber · San Francisco, CA Reposted  2 days ago  · 41 applicants
$34.50/hr (from job description) · Full-time
10,001+ employees · Software Development
2 company alumni work here
Skills: Google Workspace, Query Writing, +8 more
View verifications related to this job post.View verifications related to this job post.
Show all
"""

test_data6 = """Manager Regulatory Compliance Audits
Intuitive · Sunnyvale, CA (On-site) Reposted  2 days ago  · 57 applicants
$118,500/yr - $200,600/yr · Full-time · Mid-Senior level
5,001-10,000 employees · Medical Equipment Manufacturing
Skills: Regulatory Reporting, Regulatory Requirements, +8 more
View verifications related to this job post.View verifications related to this job post.
Show all
"""

test_data7 = """Lead ML Infrastructure Engineer
DocuSign · San Francisco, CA (Hybrid) Reposted  2 weeks ago  · 16 applicants
Full-time
5,001-10,000 employees · Software Development
1 company alum works here
Skills: Reliability, Complex Systems, +7 more
View verifications related to this job post.View verifications related to this job post.
Show all
"""

test_data8 = """Data Engineer, Product Analytics
Meta · United States (Remote) Reposted  2 weeks ago  · 280 applicants
$134,000/yr - $194,000/yr · Full-time
10,001+ employees · Software Development
8 company alumni work here
Skills: Data Engineering, Data Warehousing, +8 more
View verifications related to this job post.View verifications related to this job post.
Show all
"""

job_types = ['Full-time', 'Contract', 'Volunteer', 'Other', 'Part-time', 'Temporary', 'Internship']

# Contract Full-time
def parse_salary_range(salary_range):
    return_value = {}
    #salary_re = r"(\$[^\(]+) \(from job description\).*"
    salary_re = r"(\$[^\(]+).*"
    search_results = re.search(salary_re, salary_range)
    salary = search_results.group(1).strip()
    if salary.endswith('/hr'):
        pattern = r"\$(\d+\.\d+)/hr"
        match = re.match(pattern, salary)
        return_value['hourly_rate'] = float(match.group(1))
    else:
        pattern = r"\$(\d+?,\d+)/yr - \$(\d+?,\d+)/yr"
        match = re.match(pattern, salary)

        return_value['starting_salary_range'] = match.group(1).replace(",", "")
        return_value['ending_salary_range'] = match.group(2).replace(",", "")
    return return_value
    

def parse_job_details(job_details):
    
    lines = job_details.splitlines()
    job_data = {}
    
    # Line 1
    job_data['job_title'] = lines[0].strip()
    
    # Line 2
    line2_data = lines[1].split('·')
    job_data['company_name'] = line2_data[0].strip()
    
    if "Remote" in line2_data[1]:
        job_data['location'] = 'Remote'
    else:
        search_results = re.search(r"(.*, [A-Z]{2}) .*", line2_data[1])
        job_data['location'] = search_results.group(1).strip()
    
    search_results = re.search(r"(\d+) applicants.*", line2_data[2])
    job_data['applicants'] = search_results.group(1).strip()
    
    # Line 3
    line3_data = lines[2].split('·')
    
    if len(line3_data) == 3:
        #job_data['salary_range'] = line3_data[0].strip()
        job_data['job_type'] = line3_data[1].strip()
        job_data['experience_level'] = line3_data[2].strip()
        job_data.update(parse_salary_range(line3_data[0].strip()))
    elif len(line3_data) == 1:
        if line3_data[0].strip() in job_types:
            job_data['job_type'] = line3_data[0].strip()
        else:
            job_data['experience_level'] = line3_data[0].strip()
    else:
        if line3_data[0].strip() in job_types:
            job_data['job_type'] = line3_data[0].strip()
            job_data['experience_level'] = line3_data[1].strip()
        else:
            job_data.update(parse_salary_range(line3_data[0].strip()))
            if line3_data[1].strip() in job_types:
                job_data['job_type'] = line3_data[1].strip()
            else:
                job_data['experience_level'] = line3_data[1].strip()
       
    # Line 4
    line4_data = lines[3].split('·')
    job_data['company_size'] = line4_data[0].strip()
    job_data['industry'] = line4_data[1].strip()
    
    return {"job": job_data}
    



job_data1 = parse_job_details(test_data1)
job_data2 = parse_job_details(test_data2)
job_data3 = parse_job_details(test_data3)
job_data4 = parse_job_details(test_data4)
job_data5 = parse_job_details(test_data5)
job_data6 = parse_job_details(test_data6)
job_data7 = parse_job_details(test_data7)
job_data8 = parse_job_details(test_data8)
#print(json.dumps(job_data1, indent=4))

assert len(job_data1['job']) == 10
assert len(job_data2['job']) == 10
assert len(job_data3['job']) == 9
assert len(job_data4['job']) == 8
assert len(job_data5['job']) == 8
assert len(job_data6['job']) == 10
assert len(job_data7['job']) == 7
assert len(job_data8['job']) == 9

assert job_data5['job']['hourly_rate'] == 34.50
assert job_data2['job']['company_name'] == 'Genentech'

def materialize_job_details(linkedin_job_code, job_details):
    raw_filename = f"{linkedin_job_code}.txt"
            
    if not os.path.exists(os.path.join(directories["raw"], raw_filename)):
        with open(os.path.join(directories["raw"], raw_filename), "w") as f:
            f.write(job_details)
            f.close()

materialize_job_details('1234', test_data2)

assert os.path.exists(os.path.join(directories["raw"], '1234.txt'))
os.remove(os.path.join(directories["raw"], '1234.txt'))

# %% [markdown]
# ## Compile Pandas DataFrame

# %%
def compile_dataframe(directory):
    df_columns=['job_code', 'job_title', 'company_name', 'location', 'starting_salary_range', 'ending_salary_range', 'experience_level', 'job_type', 'company_size', 'industry', 'application_date', 'applicants']
    df = pd.DataFrame(columns=df_columns)
    for file in os.listdir(directory):
        if file.endswith('.json'):
            with open(os.path.join(directory,  file)) as f:
                new_data = pd.read_json(os.path.join(directory,  file), orient='index')
                df = pd.concat([df, new_data])
    df.set_index('job_code', inplace=True, drop=False)
    df.to_json('JAL.json', orient='index', indent=6)
    return df
    

df = compile_dataframe('jobs/json')

df.head()
# Out:
#               job_code                                          job_title
# job_code
# 3654176002  3654176002       Technical Program Manager, Data Partnerships  \
# 3648005290  3648005290  Principal Software Engineer, Cloud Microservices.
# 3651410296  3651410296                              Senior Director, Data
# 3642240092  3642240092                              Data Engineering Lead
# 3619876741  3619876741                                  Sr. Data Engineer
#
#                company_name                 location starting_salary_range
# job_code
# 3654176002  Google DeepMind        Mountain View, CA                   NaN  \
# 3648005290     Lucid Motors               Newark, CA                   NaN
# 3651410296           Tinder        San Francisco, CA                275000
# 3642240092        Genentech  South San Francisco, CA                172500
# 3619876741         Supernal              Fremont, CA                151840
#
#            ending_salary_range  experience_level   job_type
# job_code
# 3654176002                 NaN  Mid-Senior level  Full-time  \
# 3648005290                 NaN               NaN  Full-time
# 3651410296              295000  Mid-Senior level  Full-time
# 3642240092              320300         Associate  Full-time
# 3619876741              232960  Mid-Senior level  Full-time
#
#                      company_size
# job_code
# 3654176002    501-1,000 employees  \
# 3648005290  1,001-5,000 employees
# 3651410296      201-500 employees
# 3642240092      10,001+ employees
# 3619876741      201-500 employees
#
#                                                   industry application_date
# job_code
# 3654176002                               Research Services       2023-07-04  \
# 3648005290                     Motor Vehicle Manufacturing       2023-07-04
# 3651410296            Technology, Information and Internet       2023-07-04
# 3642240092                          Biotechnology Research       2023-06-28
# 3619876741  Aviation and Aerospace Component Manufacturing       2023-06-18
#
#            applicants
# job_code
# 3654176002        152
# 3648005290         23
# 3651410296        194
# 3642240092         45
# 3619876741        157

# %% [markdown]
# ### Test Initializing the Pandas DataFrame

# %%
df = pd.read_json('JAL.json', orient='index')
df.set_index("job_code", inplace=True, drop=False)
#['job_code', 'job_title', 'company_name', 'location', 'starting_salary_range', 'ending_salary_range', 'experience_level', 'job_type', 'company_size', 'industry', 'application_date', 'applicants']
    
df["application_date"] = pd.to_datetime(df["application_date"])
df["job_type"] = df["job_type"].astype("category")
df["company_size"] = df["company_size"].astype("category")
df["industry"] = df["industry"].astype("category")
df["job_code"] = df["job_code"].astype("str")

#tabulator = df[['job_code', 'job_title', 'company_name', 'application_date']]

#tabulator.head()

#df['application_date'].min()
#df['application_date'].dt.to_datetime()
#dt.date.fromtimestamp(df['application_date'].min())
df['application_date'].min().to_pydatetime()
# Out:
# datetime.datetime(2023, 6, 16, 0, 0)

# %% [markdown]
# ### BeautifulSoup
#
# Test block for parsing the html file

# %%
def beautiful_soup_test(url):
    jd = MaterializeJobData(url)
    soup = BeautifulSoup(jd, "html.parser")

    jt = soup.find("meta", {"property": "og:title"})
    company_name = re.search(r"(.*) hiring .+$", jt['content']).group(1)
    job_title = re.search(r"hiring (.*) in .+$", jt['content']).group(1)
    location = re.search(r"in (.*) \| .+$", jt['content']).group(1)

    job_data = {
        "job_title": job_title,
        "company_name": company_name,
        "location": location
    }
        
    return job_data
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# 141896

# %%
import pandas as pd
import altair as alt

source = pd.DataFrame({
    "category": [1, 2, 3, 4, 5, 6],
    "value": [4, 6, 10, 3, 7, 8]
})

company_size_summary = df.groupby("company_size")["job_code"].count()
company_size_summary = pd.DataFrame(company_size_summary).reset_index()
company_size_summary.rename(columns={"job_code": "Count"}, inplace=True)

#company_size_summary["sort_order"] = company_size_summary["company_size"].apply(lambda text: re.sub(",", "", re.search(r"(^\d{1,3}(,\d{3})*(\.\d+)?)", text).group(0)))
#company_size_summary["sort_order"] = company_size_summary["sort_order"].astype("int64")

chart = alt.Chart(company_size_summary).mark_arc().encode(
    theta="Count",
    color=alt.Color("company_size:N", sort=['51-200 employees', '201-500 employees', '501-1,000 employees', '1,001-5,000 employees', '5,001-10,000 employees', '10,000+ employees']).legend(orient="right"),
    size=alt.Size("Count"),
).properties(
    width=200
)

chart

#company_size_summary.head()
# Out:
# alt.Chart(...)

# %%
import altair as alt
#from vega_datasets import data

#source = data.population.url

pd.options.mode.chained_assignment = None
starting = df[['location', 'starting_salary_range']]
starting.rename(columns={"starting_salary_range": "salary"}, inplace=True)

ending = df[['location', 'ending_salary_range']]
ending.rename(columns={"ending_salary_range": "salary"}, inplace=True)

salary = pd.concat([starting, ending])


box_plot = alt.Chart(salary).mark_boxplot(extent='min-max').encode(
    x=alt.X('location:O', axis=alt.Axis(labelAngle=-45)),
    y='salary:Q'
).properties(width=400)

box_plot
# Out:
# alt.Chart(...)

# %%
ca_step_one = df.groupby(["application_date"]).count()
ca_step_two = ca_step_one.cumsum()
ca_step_two.index = ca_step_two.index.strftime("%Y-%m-%d")
ca_step_two.reset_index(inplace=True)
ca_step_two.rename(columns={"index": "application_date"}, inplace=True)
ca_step_two["application_date"] = pd.to_datetime(ca_step_two["application_date"])


cumulative_application_chart = (
    alt.Chart(ca_step_two.reset_index())
    .mark_line(interpolate="step-after")
    .encode(
        x=alt.X('application_date:T', axis=alt.Axis(labelAngle=-45), title="Date"),
        y=alt.Y("job_code", title="Cumulative Applications"),
        tooltip=["application_date", "job_code"],
    )
    .properties(width=800, height=400)
)
cumulative_application_chart

#step_two.head()
#step_one_chart.interactive()
# Out:
# alt.Chart(...)

# %%
# print the date difference between min and max of application_date
date_diff = df['application_date'].max() - df['application_date'].min()
application_count = df['job_code'].count()

# convert date_diff to int
delta = (dt.date.today() - df['application_date'].min().date()).days
if delta == 0:
    delta = 1
daily_application_average = df['job_code'].count() / delta
daily_application_average 
#df['application_date'].max().to_datetime() 
#help(pd.Timestamp)
#df['application_date'].max().date()
#dt.date.today()
# Out:
# 1.6111111111111112

# %%
# create a dataframe using uscities.csv. create a new field that combines city and state with a comma
# and merge with the dataframe above
cities = pd.read_csv('uscities.csv')
cities['city_state'] = cities['city'] + ', ' + cities['state_id']

# limit cities to only include cupertino, ca
#cities = cities[cities['city_state'].str.contains("Cupertino, CA")]

#cities.head()


df2 = pd.merge(df, cities, left_on='location', right_on="city_state", how='inner')
#df2.head(50)

# using altair, create a Scatter-Plots with Geographic Coordinates where the size of the circle is the number of applications

alt.Chart(df2).mark_circle().encode(
    longitude='lng_x:Q',
    latitude='lat_x:Q',
    #size=alt.value(10),
    tooltip='city_ascii_x'
).project(
    "albersUsa"
).properties(
    width=500,
    height=400
)
# Out:
#       job_code                                          job_title
# 0   3654176002       Technical Program Manager, Data Partnerships  \
# 1   3601214766        Senior Lead, Ads Data Privacy - Samsung Ads
# 2   3648005290  Principal Software Engineer, Cloud Microservices.
# 3   3651410296                              Senior Director, Data
# 4   3584767215                Engineering Manager - Data Platform
# 5   3617105127           Senior Software Engineer - Data Platform
# 6   3654739000  Staff Business Intelligence Engineer, Complian...
# 7   3634905393                    Lead ML Infrastructure Engineer
# 8   3640234903                        Trust & Safety Data Analyst
# 9   3578207790    Staff Data Engineer - Activision Blizzard Media
# 10  3616026332                            Senior BI Data Engineer
# 11  3532274360       Lead Data Engineer, Advanced Analytics Group
# 12  3629215260                                 Lead Data Engineer
# 13  3605378008                               Staff Data Architect
# 14  3638034778                       Staff Data Platform Engineer
# 15  3642240092                              Data Engineering Lead
# 16  3619876741                                  Sr. Data Engineer
# 17  3627074082            Data Architect - Digital Transformation
# 18  3433153800                                   Delivery Manager
# 19  3579689896                 Data Engineer/Senior Data Engineer
# 20  3645839402                          Manager, Data Engineering
# 21  3604579459  Data Infrastructure Engineer for Machine Learning
# 22  3604585083                           Data Engineering Manager
# 23  3579698985  Principal Data Engineer, Tech Lead (Store No.8...
# 24  3596864429                             Senior DevOps Engineer
# 25  3634670029               Senior Business Intelligence Analyst
# 26  3593216713          Principal Data Security Software Engineer
# 27  3604735442                         Business Intelligence Lead
# 28  3615121288                             Data Platform Engineer
# 29  3647290106                             Senior DevOps Engineer
# 30  3360886231                                      Data Engineer
# 31  3628371768                       IT Data and Analytics Leader
#
#                    company_name                 location
# 0               Google DeepMind        Mountain View, CA  \
# 1   Samsung Electronics America        Mountain View, CA
# 2                  Lucid Motors               Newark, CA
# 3                        Tinder        San Francisco, CA
# 4                      Nextdoor        San Francisco, CA
# 5                       Discord        San Francisco, CA
# 6                         Block        San Francisco, CA
# 7                      DocuSign        San Francisco, CA
# 8                      Nextdoor        San Francisco, CA
# 9                          King        San Francisco, CA
# 10                     Cash App        San Francisco, CA
# 11               Bain & Company        San Francisco, CA
# 12                       GoodRx        San Francisco, CA
# 13                   Databricks        San Francisco, CA
# 14                        Adobe        San Francisco, CA
# 15                    Genentech  South San Francisco, CA
# 16                     Supernal              Fremont, CA
# 17                 Lam Research              Fremont, CA
# 18                        C3 AI         Redwood City, CA
# 19                        C3 AI         Redwood City, CA
# 20                Balsam Brands         Redwood City, CA
# 21                        Apple            Cupertino, CA
# 22                        Apple            Cupertino, CA
# 23                      Walmart            San Bruno, CA
# 24                     FarmWise          Santa Clara, CA
# 25                       NVIDIA          Santa Clara, CA
# 26                       Roblox            San Mateo, CA
# 27                         Zoox          Foster City, CA
# 28          Peloton Interactive             New York, NY
# 29                          SAP            Palo Alto, CA
# 30         Luminar Technologies            Palo Alto, CA
# 31       Cadence Design Systems             San Jose, CA
#
#     starting_salary_range  ending_salary_range  experience_level   job_type
# 0                     NaN                  NaN  Mid-Senior level  Full-time  \
# 1                195000.0             245000.0  Mid-Senior level  Full-time
# 2                     NaN                  NaN              None  Full-time
# 3                275000.0             295000.0  Mid-Senior level  Full-time
# 4                155000.0             254000.0  Mid-Senior level  Full-time
# 5                190000.0             218000.0  Mid-Senior level  Full-time
# 6                     NaN                  NaN         Associate  Full-time
# 7                     NaN                  NaN              None  Full-time
# 8                 94000.0             181000.0  Mid-Senior level  Full-time
# 9                121500.0             224880.0              None  Full-time
# 10                    NaN                  NaN         Associate  Full-time
# 11               157500.0             189500.0              None  Full-time
# 12                    NaN                  NaN  Mid-Senior level  Full-time
# 13               162500.0             287700.0  Mid-Senior level  Full-time
# 14               146400.0             275000.0  Mid-Senior level  Full-time
# 15               172500.0             320300.0         Associate  Full-time
# 16               151840.0             232960.0  Mid-Senior level  Full-time
# 17               119000.0             255000.0              None  Full-time
# 18               155000.0             190000.0  Mid-Senior level  Full-time
# 19                85000.0             161000.0  Mid-Senior level  Full-time
# 20               161000.0             194000.0  Mid-Senior level  Full-time
# 21               130000.0             242000.0              None  Full-time
# 22               173000.0             299000.0              None  Full-time
# 23               168000.0             252000.0  Mid-Senior level  Full-time
# 24               172000.0             200000.0  Mid-Senior level  Full-time
# 25               180000.0             287500.0  Mid-Senior level  Full-time
# 26               315850.0             383910.0  Mid-Senior level  Full-time
# 27               193000.0             243000.0              None  Full-time
# 28               171600.0             223000.0       Entry level  Full-time
# 29               192941.0             246200.0              None  Full-time
# 30               142000.0             199000.0              None  Full-time
# 31               130200.0             241800.0  Mid-Senior level  Full-time
#
#               company_size                                        industry
# 0      501-1,000 employees                               Research Services  \
# 1    1,001-5,000 employees         Computers and Electronics Manufacturing
# 2    1,001-5,000 employees                     Motor Vehicle Manufacturing
# 3        201-500 employees            Technology, Information and Internet
# 4      501-1,000 employees            Technology, Information and Internet
# 5      501-1,000 employees                            Software Development
# 6        10,001+ employees                              Financial Services
# 7   5,001-10,000 employees                            Software Development
# 8      501-1,000 employees            Technology, Information and Internet
# 9    1,001-5,000 employees                         Entertainment Providers
# 10   1,001-5,000 employees            Technology, Information and Internet
# 11       10,001+ employees                Business Consulting and Services
# 12     501-1,000 employees                       Hospitals and Health Care
# 13  5,001-10,000 employees                            Software Development
# 14       10,001+ employees                            Software Development
# 15       10,001+ employees                          Biotechnology Research
# 16       201-500 employees  Aviation and Aerospace Component Manufacturing
# 17       10,001+ employees                     Semiconductor Manufacturing
# 18     501-1,000 employees                            Software Development
# 19     501-1,000 employees                            Software Development
# 20       201-500 employees                                          Retail
# 21       10,001+ employees         Computers and Electronics Manufacturing
# 22       10,001+ employees         Computers and Electronics Manufacturing
# 23       10,001+ employees                                          Retail
# 24        51-200 employees              Automation Machinery Manufacturing
# 25       10,001+ employees                 Computer Hardware Manufacturing
# 26   1,001-5,000 employees                            Software Development
# 27   1,001-5,000 employees                                      Automotive
# 28   1,001-5,000 employees                      Health, Wellness & Fitness
# 29       10,001+ employees                            Software Development
# 30       201-500 employees                     Motor Vehicle Manufacturing
# 31  5,001-10,000 employees                            Software Development
#
#     ... population  density source military incorporated             timezone
# 0   ...      82409   2586.4  shape    False         True  America/Los_Angeles  \
# 1   ...      82409   2586.4  shape    False         True  America/Los_Angeles
# 2   ...      47815   1335.6  shape    False         True  America/Los_Angeles
# 3   ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 4   ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 5   ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 6   ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 7   ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 8   ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 9   ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 10  ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 11  ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 12  ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 13  ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 14  ...    3290197   7199.4  shape    False         True  America/Los_Angeles
# 15  ...      66331   2805.8  shape    False         True  America/Los_Angeles
# 16  ...     231502   1160.9  shape    False         True  America/Los_Angeles
# 17  ...     231502   1160.9  shape    False         True  America/Los_Angeles
# 18  ...      83905   1687.6  shape    False         True  America/Los_Angeles
# 19  ...      83905   1687.6  shape    False         True  America/Los_Angeles
# 20  ...      83905   1687.6  shape    False         True  America/Los_Angeles
# 21  ...      60681   2038.2  shape    False         True  America/Los_Angeles
# 22  ...      60681   2038.2  shape    False         True  America/Los_Angeles
# 23  ...      43775   3141.9  shape    False         True  America/Los_Angeles
# 24  ...     127922   2677.1  shape    False         True  America/Los_Angeles
# 25  ...     127922   2677.1  shape    False         True  America/Los_Angeles
# 26  ...     105087   3297.1  shape    False         True  America/Los_Angeles
# 27  ...      33511   3370.0  shape    False         True  America/Los_Angeles
# 28  ...   18972871  10768.2  shape    False         True     America/New_York
# 29  ...      68624   1091.2  shape    False         True  America/Los_Angeles
# 30  ...      68624   1091.2  shape    False         True  America/Los_Angeles
# 31  ...    1729879   2229.0  shape    False         True  America/Los_Angeles
#
#     ranking                                               zips          id
# 0         2                      94040 94041 94043 94039 94042  1840020332  \
# 1         2                      94040 94041 94043 94039 94042  1840020332
# 2         3                                              94560  1840020295
# 3         1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 4         1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 5         1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 6         1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 7         1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 8         1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 9         1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 10        1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 11        1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 12        1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 13        1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 14        1  94130 94131 94132 94133 94134 94103 94102 9410...  1840021543
# 15        2                                        94080 94083  1840021552
# 16        2                94560 94536 94538 94539 94555 94537  1840020292
# 17        2                94560 94536 94538 94539 94555 94537  1840020292
# 18        3                            94065 94062 94063 94061  1840020304
# 19        3                            94065 94062 94063 94061  1840020304
# 20        3                            94065 94062 94063 94061  1840020304
# 21        2                            95014 95015 95108 95170  1840018950
# 22        2                            95014 95015 95108 95170  1840018950
# 23        2                                              94066  1840021549
# 24        2          95054 95050 95051 95053 95052 95055 95056  1840021571
# 25        2          95054 95050 95051 95053 95052 95055 95056  1840021571
# 26        2                      94404 94401 94402 94403 94497  1840021551
# 27        2                                              94404  1840020302
# 28        1  11229 11226 11225 11224 11223 11221 11220 1138...  1840034016
# 29        3          94028 94022 94303 94301 94306 94304 94302  1840020333
# 30        3          94028 94022 94303 94301 94306 94304 94302  1840020333
# 31        1  95118 95128 95124 95125 95126 95127 95120 9512...  1840021570
#
#                  city_state
# 0         Mountain View, CA
# 1         Mountain View, CA
# 2                Newark, CA
# 3         San Francisco, CA
# 4         San Francisco, CA
# 5         San Francisco, CA
# 6         San Francisco, CA
# 7         San Francisco, CA
# 8         San Francisco, CA
# 9         San Francisco, CA
# 10        San Francisco, CA
# 11        San Francisco, CA
# 12        San Francisco, CA
# 13        San Francisco, CA
# 14        San Francisco, CA
# 15  South San Francisco, CA
# 16              Fremont, CA
# 17              Fremont, CA
# 18         Redwood City, CA
# 19         Redwood City, CA
# 20         Redwood City, CA
# 21            Cupertino, CA
# 22            Cupertino, CA
# 23            San Bruno, CA
# 24          Santa Clara, CA
# 25          Santa Clara, CA
# 26            San Mateo, CA
# 27          Foster City, CA
# 28             New York, NY
# 29            Palo Alto, CA
# 30            Palo Alto, CA
# 31             San Jose, CA
#
# [32 rows x 30 columns]
